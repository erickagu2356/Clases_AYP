# %%
contador=1
while contador<=5:
  print("Contando= ",contador)
  contador+=1 #Es lo mismo que contador==contador+1
# Out:
# Contando=  1
# Contando=  2
# Contando=  3
# Contando=  4
# Contando=  5

# %%
Numero= 0
while True:
  Numero+=2
  print("El valor de el numero es: ", Numero)
  if Numero>=11:
    print("Se finaliza el ciclo")
    break
# Out:
# El valor de el numero es:  2
# El valor de el numero es:  4
# El valor de el numero es:  6
# El valor de el numero es:  8
# El valor de el numero es:  10
# El valor de el numero es:  12
# Se finaliza el ciclo

# %%
num=float(input("Ingrese el numero a sumar: "))
Sum=num
while num!=0:
  num=float(input("Ingrese el numero a sumar: "))
  Sum += num
print("La suma de todos los numeros es: ",Sum)
# Out:
# Ingrese el numero a sumar: 5
# Ingrese el numero a sumar: 5
# Ingrese el numero a sumar: 5
# Ingrese el numero a sumar: 0
# La suma de todos los numeros es:  15.0

# %%
import random #Juego de adivinar el numero generado aleatoriamente por el modulo randint
po= random.randint(1,10)
print(random)
num=int(input("Adivine el numero: "))
contador=1
while num!= po:
    print("Numero incorrecto")
    if num>po:
      print("El numero a divinar es menor")
    else :
      print ("El numero a adivinar es mayor")
    num=int(input("Adivine el numero: "))
    contador+=1
print(f"Adivinaste el numero en {contador} intentos")
# Out:
# <module 'random' from '/usr/lib/python3.12/random.py'>
# Adivine el numero: 4
# Numero incorrecto
# El numero a adivinar es mayor
# Adivine el numero: 6
# Numero incorrecto
# El numero a divinar es menor
# Adivine el numero: 5
# Adivinaste el numero en 3 intentos

# %%
contra="222222"
ipo=input("Ingrese la contraseña: ")
while ipo!=contra:
  ipo=input("Ingrese la contraseña: ")

print("Acceso concedido")
# Out:
# Ingrese la contraseña: 2
# Ingrese la contraseña: 222222
# Acceso concedido

# %% [markdown]
# def nombre_funcion(argumentos):
#   codigo
# return retorno
# Las funciones se componen de

# %%
def di_hola():#Forma de crear una función
  print("Hola")

# %%
di_hola()
# Out:
# Hola

# %%
def di_hola(nombre):
  print("Hola",nombre)

# %%
di_hola("Juan")
# Out:
# Hola Juan

# %%
def resta(a,b):
  c=a-b
  return c #Para devolver la variable que necesite

# %%
resultado= resta(8,3)#Hay que tener cuidado con el orden porque si no se insertan bien los elemnetos puede arrojar un resultado diferente
#print(resultado)#Si yo inserto 1 o mas de 2 vaores en la resta da error

# %%
resta(b=3,a=8)#Cuando yo le asigno los nombres a cada elemento no importa el orden
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14847/4258463729.py in <cell line: 0>()
# ----> 1 resta(b=3,a=8)#Cuando yo le asigno los nombres a cada elemento no importa el orden
#
# NameError: name 'resta' is not defined

# %%
def resta1(a,b,c=0):#Si yo le asigno un numero a una variable ya no dara error al no escriirla cuando la pidan
  return a-b+c

# %%
resultado1=resta1(a=1,b=5)
print(resultado1)
# Out:
# -4

# %%
def resta2(a=0,b=0,c=0):
  return a-b+c,c-a-b#Si hago dos procedimientos y los separo con una coma el me dara una tupla con 2 resultados

# %%
resta2(1,2, 3)#Ejemplo
# Out:
# (2, 0)

# %%
resulta1,resulta2= resta2(2,3,6)#Forma de aprovechar dos formas sin creara otra funcion para otra operacion
print("El resultado1 es: ",resulta1)
print("El resultado2 es: ",resulta2)
# Out:
# El resultado1 es:  5
# El resultado2 es:  1

# %%
def areatriangulo(base,altura):#ejercicio area del triangulo
 area=base*altura/2
 print("El area es: ",area)
#return area

# %%
areatriangulo(2,3)
areatriangulo(3,4)
areatriangulo(4,5)
areatriangulo(5,6)
# Out:
# El area es:  3.0
# El area es:  6.0
# El area es:  10.0
# El area es:  15.0

# %%
def num_mayor(a,b,c):
  d=[a,b,c]
  return max(d)

# %%
numero_mayor= num_mayor(55,-8,64.3)
print(numero_mayor)
# Out:
# 64.3

# %%
def n_pares(lista):
  n_lista=[]
  for i in lista:#Forma de escanear los elementos de la lista
   if i % 2==0:
    n_lista.append(i)
  return n_lista

# %%
lista=[2,7,9,87,12,45,44,46,48,24,56]
lista_pares= n_pares(lista)
print(lista_pares)
# Out:
# [2, 12, 44, 46, 48, 24, 56]

# %%
def factorial(N):
 num_fac=1
 for i in  range(1,N+1):
  num_fac == num_fac*i
  print(num_fac)
 return num_fac

# %%
factorial(5)
# Out:
# 1
# 1
# 1
# 1
# 1
# 1

# %%
lista_num=[1,24.5,14,29] #De esta forma se crea una lista
print(lista_num)
# Out:
# [1, 24.5, 14, 29]

# %%
a= 2
b=[]
dir(b)#En los metodos solo vamos a utilizar los que no tienen dole guion bajo
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lista_vacia=[]#El metodo .append funciona para añadir o almacenar datos a mi lista
lista_vacia.append(1)
lista_vacia.append(2)
print(lista_vacia)
# Out:
# [1, 2]

# %%
sum(lista_vacia)
# Out:
# 3

# %%
len(lista_vacia)#len sirve para decirnos la cantidad de datos que hay en mi lista
# Out:
# 1

# %%
min(lista_vacia)
# Out:
# 1

# %%
max(lista_vacia)
# Out:
# 2

# %%
lista_vacia[-2]
# Out:
# 1

# %%
#dato1=ciudad, dato2= nombre, dato3=edad, dato4=trabaja?, dato5,estudia
datos_camilo=["Medellin","Camilo",23,True, "Si"]
datos_ana=["Bogotá","Ana", 25,False, "Si"]

# %%
camilo_trabaja=datos_camilo[3]
ana_estudia= datos_ana[4]

# %%
datos_camilo[0:1+1]#mi_lista[posicion inicial: posición final +1] en este caso entre los datos de entre 0 y 2 sin contal el 2
# Out:
# ['Medellin', 'Camilo']

# %%
datos_ana[-3:]# si yo coloco solo la parte de posicion incial, el programa interpreta que quieres los datos hasta el ultimo
# Out:
# [25, False, 'Si']

# %%
datos=[datos_camilo[1:4], datos_ana[1:4]]#lista de listas
print(datos)
# Out:
# [['Camilo', 23, True], ['Ana', 25, False]]

# %%
datos[0][2]# para acceder a los datos de lista de listas se coloca primero la posicion de la lista que esta dentro de ella y luego la posicion del valor en su lista
# Out:
# True

# %%
datos.append(["Camila", 20, True])
print(datos)#Si se ejecuta la linea en la que insertas datos varias veces se agregaran los datos el numero de veces que lo hiciste
# Out:
# [['Camilo', 23, True], ['Ana', 25, False], ['Camila', 20, True], ['Camila', 20, True], ['Camila', 20, True], ['Camila', 20, True], ['Camila', 20, True], ['Camila', 20, True], ['Camila', 20, True]]

# %%
datos=datos[0:3]
print(datos)
# Out:
# [['Camilo', 23, True], ['Ana', 25, False], ['Camila', 20, True]]

# %%
lista=[2,1,8,7,9,3,5]

# %%
lista.pop(5)
# Out:
# 3

# %%
lista.append(1)
lista.append(3)

# %%
print(lista)
# Out:
# [2, 1, 8, 7, 9, 5, 0, 1, 3]

# %%
lista.sort()

# %%
print(lista)
# Out:
# [0, 1, 1, 2, 3, 5, 7, 8, 9]

# %%
max(lista)
# Out:
# 9

# %%
min(lista)
# Out:
# 0

# %%
sum(lista)
# Out:
# 36

# %%
len(lista)
# Out:
# 9

# %%
promedio=(sum(lista))/len(lista)
print("El promedio es: ", promedio)
# Out:
# El promedio es:  4.0

# %%
lista.clear()
print(lista)
# Out:
# []
